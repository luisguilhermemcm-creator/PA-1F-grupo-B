# %% [markdown]
# <a href="https://colab.research.google.com/github/luisguilhermemcm-creator/PA-1F-grupo-B/blob/main/26_05_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Projeto caixa eletrônico

#Você foi contratado para desenvolver um sistema simples de caixa eletrônico

#O sistema deverá funcionar através de um menu interativo utilizando "while"

#O programa deve iniciar com um um saldo de R$ 1000,00 e permitir que o usuário
#escolha diferentes operaçoes até decidir


saldo = 1000.00
opcao = 0

while opcao != 4:
  print("-------MENU-------")
  print("")
  print("Opção 1 - Consultar saldo")
  print("Opção 2 - Saque")
  print("Opção 3 - Depósito")
  print("Opção 4 - Sair")
  print("")


  opcao = int(input("Escolha a opção desejada: "))

  if opcao == 1:
    print(f"Seu saldo é de R$ {saldo}")

  elif opcao == 2:
    saque = float(input("Digite o valor do saque: "))

    if saque > saldo:
        print("Saldo insuficiente")

    else:
        saldo -= saque
        print(f"Saque de R$ {saque} realizado com sucesso")
        print(f"Seu saldo atual é de R$ {saldo}")

  elif opcao == 3:
        deposito = float(input("Digite o valor do depósito: "))
        saldo += deposito
        print(f"Depósito de R$ {deposito} realizado com sucesso")
        print(f"Seu saldo atual é de R$ {saldo}")

  elif opcao == 4:
      print("")
      print("Obrigado por usar o caixa eletrônico")
      break

  else:
        print("Opção inválida")
# Out:
# -------MENU-------
#
# Opção 1 - Consultar saldo
# Opção 2 - Saque
# Opção 3 - Depósito
# Opção 4 - Sair
#
# Escolha a opção desejada: 3
# Digite o valor do depósito: 500
# Depósito de R$ 500.0 realizado com sucesso
# Seu saldo atual é de R$ 1500.0
# -------MENU-------
#
# Opção 1 - Consultar saldo
# Opção 2 - Saque
# Opção 3 - Depósito
# Opção 4 - Sair
#
# Escolha a opção desejada: 2
# Digite o valor do saque: 1400
# Saque de R$ 1400.0 realizado com sucesso
# Seu saldo atual é de R$ 100.0
# -------MENU-------
#
# Opção 1 - Consultar saldo
# Opção 2 - Saque
# Opção 3 - Depósito
# Opção 4 - Sair
#
# Escolha a opção desejada: 1
# Seu saldo é de R$ 100.0
# -------MENU-------
#
# Opção 1 - Consultar saldo
# Opção 2 - Saque
# Opção 3 - Depósito
# Opção 4 - Sair
#
# Escolha a opção desejada: 4
#
# Obrigado por usar o caixa eletrônico

# %%
#Calculadora simples

opcao = ""
numero_a = 0
numero_b = 0

print ("-------MENU-------")
print ("")
print ("Opção 1 - Soma")
print ("Opção 2 - Subtração")
print ("Opção 3 - Multiplicação")
print ("Opção 4 - Divisão")
print ("Oção 5 - Sair")
print ("")

try:

  while opcao != 5:
    opcao = int (input("Escolha a opção desejada ou 5 para sair!: "))

    if opcao == 1:

      numero_a = float (input("Digite o primeiro número: "))
      numero_b = float (input("Digite o segundo número: "))

      print (f"A soma de {numero_a} + {numero_b} é igual a {numero_a + numero_b}")

    elif opcao == 2:

      numero_a = float (input("Digite o primeiro número: "))
      numero_b = float (input("Digite o segundo número: "))

      print(f"A subtração de {numero_a} - {numero_b} é igual a {numero_a - numero_b}")

    elif opcao == 3:

      numero_a = float (input("Digite o primeiro número: "))
      numero_b = float (input("Digite o segundo número: "))

      print(f"A multiplicação de {numero_a} X {numero_b} é {numero_a * numero_b}")

    elif opcao == 4:

      numero_a = float (input("Digite o primeiro número: "))
      numero_b = float (input("Digite o segundo número: "))

      print(f"A divisão de {numero_a} / {numero_b} é {numero_a / numero_b}")

except:
  print ("Digite apenas números ")
