# %% [markdown]
# <a href="https://colab.research.google.com/github/luisguilhermemcm-creator/PA-1F-grupo-B/blob/main/Float_src_input_aula_3_17_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada

lado1 = float (input("Digite o comprimento:"))
lado2 = float (input("Digite a altura:"))

# Processamento

area = lado1 * lado2

# Saida

print (f"O total da area é :{area} metros quadrados")
# Out:
# Digite o comprimento:5
# Digite a altura8
# O total da area é :40.0 metros quadrados

# %% [markdown]
# Escrever um programa que calcula o dobre de um numero.

# %%
#entrada
numero1 = float (input("digite um numero:"))

#processo

dobro = numero1 * 2

 #saida

print (f"o dobro do numero {numero1} é : {dobro}")
# Out:
# digite um numero:5
# o dobro do numero 5.0 é : 10.0

# %% [markdown]
# Fazer um programa que o usuario irá entrar com 04 notas , vamos calcular a média e mostrar o usuario a média

# %%
#entrada

numero1 = float (input("digite o primeiro numero "))
numero2 = float (input("digite o segundo numero "))
numero3 = float (input("digite o terceiro numero "))
numero4 = float (input("digite o quarto numero "))

#processamento

Media = numero1 + numero2 + numero3 + numero4
resultado = Media/4

#saida

print (f"a media dos 4 numeros é {resultado}")
# Out:
# digite o primeiro numero 5
# digite o segundo numero 8
# digite o terceiro numero 98
# digite o quarto numero 7
# a media dos 4 numeros é 29.5

# %% [markdown]
# Fazer um cadastro simples de usuario
#
# Objetivo: usar String (str)
#
# Logica
#
# Entrada: nome e idade
# Processamento: armazenar
# Saida: Exibir uma mensagem olá (nome), você tem x anos

# %%
#entrada
nome = str (input("digite seu nome:"))
idade = int (input("digite sua idade:"))

#processamento


#saida

print (f"ola {nome} você tem {idade} anos")
# Out:
# digite seu nome:5
# digite sua idade:8
# ola 5 você tem 8 anos
